# %% [markdown]
# ### 機器學習 = 機器自動找一個函式產生我們想要的輸出
#
# ![what_is_ml.png](attachment:628b4d70-8e7d-4fd2-929e-9f7c9ea12f45.png)

# %% [markdown]
# ### 依據函式輸出來分類
# 1. Regression: 輸出數值
# 2. Classification: 輸出類別 (選擇題)
# 3. Structured Learning: 輸出有結構的物件(影像、文句) (aka. Generative Learning)

# %% [markdown]
# ### 找函式一加三步驟:
# 0. 決定要找什麼樣的函數: 取決於想要做的應用
#
# 1. 設定範圍:
# ![Screenshot 2023-03-04 at 9.12.20 PM.png](attachment:79dd24a1-ebbe-4220-883e-abcf237ef1d1.png)
# * Fully-connected > CNN
# * Self-attention > CNN
# * 範圍大適用於資料大的情形
#
# 2. 設定標準:
# ![Screenshot 2023-03-04 at 9.47.19 PM.png](attachment:6981245b-8fcc-4807-8ec6-bb7f38ada3c1.png)
#
# 3. 達成目標:
# ![1_optimization.png](attachment:c0053c29-23b3-4aa0-8369-19b40d4795c8.png)
